# %% [markdown]
# # **step one we have to import required libraries and we have to upload the csv file then we have to convert it into dataframe**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('S.csv')
df=pd.DataFrame(df)
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
df['Date']=pd.to_datetime(df['Date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %%
df=df.head(10)
plt.plot(df['week'],df['Quantity'])

# %%
df['Month']=pd.to_datetime(df['Date']).dt.month
df['Year']=pd.to_datetime(df['Date']).dt.year
df['week']=pd.to_datetime(df['Date']).dt.isocalendar().week
df['Time']=pd.to_datetime(df['Time'])
df['hour']=pd.to_datetime(df['Time']).dt.hour
df
# Out:
# /tmp/ipython-input-1773028308.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Month']=pd.to_datetime(df['Date']).dt.month
# /tmp/ipython-input-1773028308.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year']=pd.to_datetime(df['Date']).dt.year
# /tmp/ipython-input-1773028308.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
plt.bar(df['Gender'],df['gross income'])
plt.grid()

# %%
plt.hist(df['Total'])


plt.show()
# Out:
# (array([2., 1., 0., 1., 0., 2., 1., 1., 1., 1.]),
#  array([ 76.146 , 145.7694, 215.3928, 285.0162, 354.6396, 424.263 ,
#         493.8864, 563.5098, 633.1332, 702.7566, 772.38  ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(df['Total'])
plt.show()

# %%
gender_total = df.groupby('Gender')['Total'].sum()
plt.pie(gender_total, labels=gender_total.index, autopct='%1.2f%%')
plt.show()

# %%
plt.scatter(df['Rating'],df['Quantity'],c=df['Quantity'],cmap='viridis',mec=,mfc=,s)

plt.colorbar()
plt.grid()

# %%
plt.figure(figsize=(12,6))
plt.subplot(2,3,1)
plt.plot(df['week'],df['Quantity'])
plt.title('Quantity by Week')


plt.subplot(2,3,2)
plt.scatter(df['Rating'],df['Quantity'],c=df['Quantity'],cmap='viridis',s=50)
plt.colorbar()
plt.grid()
plt.title('Quantity vs Rating')


plt.subplot(2,3,3)
plt.boxplot(df['Total'])
plt.title('Total Sales Distribution')


plt.subplot(2,3,4)
plt.hist(df['Total'])
plt.title('Total Sales Histogram')


plt.subplot(2,3,5)
plt.bar(df['Gender'],df['gross income'])
plt.title('Gross Income by Gender',fontdict={'family':'serif','fontsize':20,'color':'cyan'})

plt.suptitle('SUBPLOTS')

plt.tight_layout() # Adjust layout to prevent title overlap
plt.show()
